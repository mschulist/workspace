# %%
import numpy as np

# %%
def f(x):
    return abs(1 / 2 - np.sqrt(x**2 + x) + x)

# %%
for e1 in range(100):
    e = 10**(-e1+10)
    N = np.ceil(1/e)

    print(f(N), e)
    if f(N) >= e:
        print("FAILED")
# Out:
# 0.08578643762690485 10000000000
# 0.08578643762690485 1000000000
# 0.08578643762690485 100000000
# 0.08578643762690485 10000000
# 0.08578643762690485 1000000
# 0.08578643762690485 100000
# 0.08578643762690485 10000
# 0.08578643762690485 1000
# 0.08578643762690485 100
# 0.08578643762690485 10
# 0.08578643762690485 1
# 0.01191151829848458 0.1
# 0.0012437887911005419 0.01
# 0.0001249375389988927 0.001
# 1.2499374861363322e-05 0.0001
# 1.2499949662014842e-06 1e-05
# 1.25030055642128e-07 1e-06
# 1.30385160446167e-08 1e-07
# 0.0 1e-08
# 0.0 1e-09
# 0.0 1e-10
# 0.0 1e-11
# 0.0 1e-12
# 0.0 1e-13
# 0.0 1e-14
# 0.0 1e-15
# 2.0 1e-16
# FAILED
# 0.0 1e-17
# 0.0 1e-18
# 0.0 1e-19
# 0.0 1e-20
# 0.0 1e-21
# 0.0 1e-22
# 0.0 1e-23
# 0.0 1e-24
# 0.0 1e-25
# 0.0 1e-26
# 0.0 1e-27
# 0.0 1e-28
# 0.0 1e-29
# 0.0 1e-30
# 0.0 1e-31
# 0.0 1e-32
# 0.0 1e-33
# 0.0 1e-34
# 0.0 1e-35
# 0.0 1e-36
# 0.0 1e-37
# 0.0 1e-38
# 0.0 1e-39
# 0.0 1e-40
# 0.0 1e-41
# 0.0 1e-42
# 0.0 1e-43
# 0.0 1e-44
# 0.0 1e-45
# ...
