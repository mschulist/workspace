# %%
import matplotlib.pyplot as plt
import scipy.constants as consts
import numpy as np

# %%
def psi(x, x_0):
    return (x - x_0)

# %%
m = 1
omega = 1

xs = np.linspace(-1,1)
ys = psi(xs, np.sqrt(consts.hbar / (m * omega)))

plt.plot(xs, ys)
plt.show()
